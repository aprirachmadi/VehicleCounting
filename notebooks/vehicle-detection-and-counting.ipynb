# %%
# !pip install ultralytics
# !pip install supervision==0.14.0
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.2.77-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.5.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.1.2)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.16.2)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ultralytics) (5.9.3)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.12.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2024.7.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.13.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2024.5.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.2.77-py3-none-any.whl (869 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.0/869.0 kB 9.4 MB/s eta 0:00:00:00:0100:01
# Downloading ultralytics_thop-2.0.0-py3-none-any.whl (25 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.2.77 ultralytics-thop-2.0.0
# Collecting supervision==0.14.0
#   Downloading supervision-0.14.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.1 in /opt/conda/lib/python3.10/site-packages (from supervision==0.14.0) (3.7.5)
# Requirement already satisfied: numpy<2.0.0,>=1.20.0 in /opt/conda/lib/python3.10/site-packages (from supervision==0.14.0) (1.26.4)
# Requirement already satisfied: opencv-python-headless<5.0.0.0,>=4.8.0.74 in /opt/conda/lib/python3.10/site-packages (from supervision==0.14.0) (4.10.0.84)
# Requirement already satisfied: pillow<10.0.0,>=9.4.0 in /opt/conda/lib/python3.10/site-packages (from supervision==0.14.0) (9.5.0)
# Requirement already satisfied: pyyaml<7.0,>=6.0 in /opt/conda/lib/python3.10/site-packages (from supervision==0.14.0) (6.0.1)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from supervision==0.14.0) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->supervision==0.14.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->supervision==0.14.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->supervision==0.14.0) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->supervision==0.14.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->supervision==0.14.0) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->supervision==0.14.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->supervision==0.14.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.7.1->supervision==0.14.0) (1.16.0)
# Downloading supervision-0.14.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: supervision
# Successfully installed supervision-0.14.0

# %%
import ultralytics
print("ultralytics.__version__:", ultralytics.__version__)

import supervision
print("supervision.__version__:", supervision.__version__)

import torch
print("torch.__version__:", torch.__version__)

print("CUDA Device:", torch.cuda.get_device_name(0))
# Out:
# ultralytics.__version__: 8.2.77
# supervision.__version__: 0.14.0
# torch.__version__: 2.1.2
# CUDA Device: Tesla T4

# %% [markdown]
# # Tracking

# %%
from ultralytics import YOLO

video_path = '/kaggle/input/toll-gate/toll_gate.mp4'

# Configure the tracking parameters and run the tracker
model = YOLO('yolov8x.pt')

results = model.track(source=video_path,  classes=[2, 5], conf=0.3, iou=0.5, save=True, tracker="bytetrack.yaml")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8x.pt to 'yolov8x.pt'...
# 100%|██████████| 131M/131M [00:00<00:00, 137MB/s]
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Collecting lapx>=0.5.2
#   Downloading lapx-0.5.9.post1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy>=1.21.6 in /opt/conda/lib/python3.10/site-packages (from lapx>=0.5.2) (1.26.4)
# Downloading lapx-0.5.9.post1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 36.7 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: lapx
# Successfully installed lapx-0.5.9.post1
#
# requirements: AutoUpdate success ✅ 11.7s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 1 car, 1 bus, 107.0ms
# video 1/1 (frame 2/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 1 car, 1 bus, 62.0ms
# video 1/1 (frame 3/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 1 car, 1 bus, 61.9ms
# video 1/1 (frame 4/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 1 car, 1 bus, 61.8ms
# video 1/1 (frame 5/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 1 car, 1 bus, 62.0ms
# video 1/1 (frame 6/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 1 car, 1 bus, 35.4ms
# video 1/1 (frame 7/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 1 car, 1 bus,
358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 3 cars, 31.9ms
# video 1/1 (frame 340/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 3 cars, 32.6ms
# video 1/1 (frame 341/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 3 cars, 33.6ms
# video 1/1 (frame 342/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 3 cars, 33.2ms
# video 1/1 (frame 343/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 3 cars, 32.5ms
# video 1/1 (frame 344/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 3 cars, 32.7ms
# video 1/1 (frame 345/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 3 cars, 33.5ms
# video 1/1 (frame 346/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 3 cars, 34.1ms
# video 1/1 (frame 347/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 3 cars, 32.3ms
# video 1/1 (frame 348/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 3 cars, 32.1ms
# video 1/1 (frame 349/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 3 cars, 32.5ms
# video 1/1 (frame 350/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 3 cars, 33.3ms
# video 1/1 (frame 351/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 3 cars, 34.1ms
# video 1/1 (frame 352/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 3 cars, 32.4ms
# video 1/1 (frame 353/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 3 cars, 32.4ms
# video 1/1 (frame 354/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 3 cars, 32.9ms
# video 1/1 (frame 355/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 3 cars, 33.9ms
# video 1/1 (frame 356/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 3 cars, 32.2ms
# video 1/1 (frame 357/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 3 cars, 32.8ms
# video 1/1 (frame 358/358) /kaggle/input/toll-gate/toll_gate.mp4: 384x640 3 cars, 32.9ms
# Speed: 2.1ms preprocess, 33.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track

# %% [markdown]
# # Tracking and counting  - Multiple Gate

# %%
import cv2
cap = cv2.VideoCapture(video_path)
cap.get(cv2.CAP_PROP_FRAME_WIDTH), cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
# Out:
# (596.0, 336.0)

# %%
from collections import defaultdict
import supervision as sv
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('yolov8x.pt')

# Set up video capture
cap = cv2.VideoCapture(video_path)

# Define the line coordinates up to 8 gates
START_1, END_1 = sv.Point(10, 135), sv.Point(87, 151)
START_2, END_2 = sv.Point(87, 151), sv.Point(152, 166)
START_3, END_3 = sv.Point(152, 166), sv.Point(219, 180)
START_4, END_4 = sv.Point(219, 180), sv.Point(287, 195)
START_5, END_5 = sv.Point(287, 195), sv.Point(356, 210)
START_6, END_6 = sv.Point(356, 210), sv.Point(428, 226)
START_7, END_7 = sv.Point(390, 245), sv.Point(486, 267)
START_8, END_8 = sv.Point(486, 267), sv.Point(562, 284)

            
# Define the gates
gates = [
    (START_1, END_1),
    (START_2, END_2),
    (START_3, END_3),
    (START_4, END_4),
    (START_5, END_5),
    (START_6, END_6),
    (START_7, END_7),
    (START_8, END_8)
]

# Store the track history
track_history = defaultdict(lambda: [])

# Create a dictionary to keep track of objects that have crossed the line
crossed_objects = [defaultdict(bool) for _ in range(8)]

# Counters for cars and buses
car_count = 0
bus_count = 0

# Open a video sink for the output video
video_info = sv.VideoInfo.from_video_path(video_path)
with sv.VideoSink("output_multi_gate_vehicle_detection.mp4", video_info) as sink:

    while cap.isOpened():
        success, frame = cap.read()

        if success:
            # Run YOLOv8 tracking on the frame, persisting tracks between frames
            results = model.track(frame,  classes=[2, 5], conf=0.3, iou=0.5, persist=True, tracker="bytetrack.yaml")

            # Get the boxes and track IDs
            boxes = results[0].boxes.xywh.cpu()
            track_ids = results[0].boxes.id.int().cpu().tolist()
            class_ids = results[0].boxes.cls.int().cpu().tolist()

            # Visualize the results on the frame
            annotated_frame = results[0].plot()
            detections = sv.Detections.from_ultralytics(results[0])

            # Plot the tracks and count objects crossing the line
            for box, track_id, class_id in zip(boxes, track_ids, class_ids):
                x, y, w, h = box
                track = track_history[track_id]
                track.append((float(x), float(y)))  # x, y center point
                if len(track) > 30:  # retain 30 tracks for 30 frames
                    track.pop(0)

                for i, (start, end) in enumerate(gates):
                    # Check if the object crosses the line
                    if start.x < x < end.x and start.y < y < end.y:
                        # Mark the object as crossed
                        if not crossed_objects[i][track_id]:
                            crossed_objects[i][track_id] = True
                            # add the counters based on the class ID
                            if class_id == 2:  # Car
                                car_count += 1
                            elif class_id == 5:  # Bus
                                bus_count += 1

                        # Annotate the object as it crosses the line
                        cv2.rectangle(annotated_frame, (int(x - w / 2), int(y - h / 2)),
                                        (int(x + w / 2), int(y + h / 2)), (0, 255, 0), 2)
                        
            # Draw the line on the frame
            for start, end in gates:
                cv2.line(annotated_frame, (start.x, start.y), (end.x, end.y), (0, 255, 0), 2)

            # Label the gates
            for i, xpos in enumerate([50, 115, 180, 250, 315, 380, 460, 535]):
                gate_text = f"{i+1}"
                cv2.putText(annotated_frame, gate_text, (xpos, int((60771 + 125*xpos)/569)),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)

            # Write the number of Vehicle get through the gate
            for i, ypos in enumerate(range(20, 100, 10)):
                count_text = f"Objects crossed gate {i+1}: {len(crossed_objects[i])}"
                cv2.putText(annotated_frame, count_text, (10, ypos), cv2.FONT_HERSHEY_SIMPLEX,
                            0.5, (0, 0, 0), 1, cv2.LINE_AA)
            
            # Display the vehicle counts on the frame
            cv2.putText(annotated_frame, f"Cars: {car_count}", (310, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (255, 0, 0), 2, cv2.LINE_AA)
            cv2.putText(annotated_frame, f"Buses: {bus_count}", (310, 70), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (255, 0, 0), 2, cv2.LINE_AA)

            # Write the frame with annotations to the output video
            sink.write_frame(annotated_frame)
        else:
            break

# Release the video capture
cap.release()
# Out:
# 0: 384x640 1 car, 1 bus, 61.3ms
# Speed: 1.8ms preprocess, 61.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 59.4ms
# Speed: 2.2ms preprocess, 59.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 44.6ms
# Speed: 1.4ms preprocess, 44.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 33.9ms
# Speed: 1.6ms preprocess, 33.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 33.3ms
# Speed: 2.1ms preprocess, 33.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 34.7ms
# Speed: 1.6ms preprocess, 34.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 34.0ms
# Speed: 2.1ms preprocess, 34.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 32.8ms
# Speed: 1.4ms preprocess, 32.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 33.0ms
# Speed: 1.4ms preprocess, 33.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 33.4ms
# Speed: 2.2ms preprocess, 33.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 35.1ms
# Speed: 2.0ms preprocess, 35.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 33.3ms
# Speed: 1.5ms preprocess, 33.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 35.1ms
# Speed: 2.0ms preprocess, 35.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 33.9ms
# Speed: 2.1ms preprocess, 33.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 33.2ms
# Speed: 2.2ms preprocess, 33.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 33.5ms
# Speed: 1.8ms preprocess, 33.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 35.1ms
# Speed: 1.6ms preprocess, 35.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus,
9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 33.9ms
# Speed: 2.1ms preprocess, 33.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 34.7ms
# Speed: 1.4ms preprocess, 34.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 34.9ms
# Speed: 1.6ms preprocess, 34.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 33.9ms
# Speed: 1.6ms preprocess, 33.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 34.2ms
# Speed: 1.4ms preprocess, 34.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 35.5ms
# Speed: 1.4ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 33.1ms
# Speed: 1.7ms preprocess, 33.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.9ms
# Speed: 2.0ms preprocess, 32.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 33.3ms
# Speed: 1.6ms preprocess, 33.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 34.7ms
# Speed: 2.1ms preprocess, 34.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 34.7ms
# Speed: 1.5ms preprocess, 34.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.8ms
# Speed: 2.2ms preprocess, 32.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 33.5ms
# Speed: 1.5ms preprocess, 33.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 34.3ms
# Speed: 2.1ms preprocess, 34.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 34.9ms
# Speed: 1.6ms preprocess, 34.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 34.8ms
# Speed: 1.5ms preprocess, 34.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 33.2ms
# Speed: 1.7ms preprocess, 33.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.8ms
# Speed: 1.7ms preprocess, 32.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 34.4ms
# Speed: 1.7ms preprocess, 34.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 34.6ms
# Speed: 1.6ms preprocess, 34.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 33.0ms
# Speed: 2.1ms preprocess, 33.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 33.2ms
# Speed: 1.4ms preprocess, 33.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 34.5ms
# Speed: 1.5ms preprocess, 34.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 34.9ms
# Speed: 2.1ms preprocess, 34.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 33.2ms
# Speed: 1.5ms preprocess, 33.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 33.1ms
# Speed: 2.1ms preprocess, 33.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 34.4ms
# Speed: 1.5ms preprocess, 34.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 35.3ms
# Speed: 1.5ms preprocess, 35.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 32.8ms
# Speed: 2.1ms preprocess, 32.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 34.3ms
# Speed: 2.1ms preprocess, 34.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 36.2ms
# Speed: 1.5ms preprocess, 36.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 34.2ms
# Speed: 1.5ms preprocess, 34.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 33.4ms
# Speed: 2.1ms preprocess, 33.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 35.2ms
# Speed: 1.5ms preprocess, 35.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 buss, 33.6ms
# Speed: 1.6ms preprocess, 33.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 buss, 33.3ms
# Speed: 1.6ms preprocess, 33.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 buss, 33.5ms
# Speed: 2.1ms preprocess, 33.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 buss, 35.9ms
# Speed: 1.6ms preprocess, 35.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 buss, 34.4ms
# Speed: 1.6ms preprocess, 34.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 buss, 32.7ms
# Speed: 2.6ms preprocess, 32.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 buss, 34.1ms
# Speed: 2.4ms preprocess, 34.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 buss, 32.5ms
# Speed: 1.6ms preprocess, 32.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 buss, 33.1ms
# Speed: 1.7ms preprocess, 33.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 buss, 35.1ms
# Speed: 1.4ms preprocess, 35.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 buss, 32.8ms
# Speed: 2.1ms preprocess, 32.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 33.5ms
# Speed: 1.5ms preprocess, 33.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 34.1ms
# Speed: 1.6ms preprocess, 34.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 36.5ms
# Speed: 1.5ms preprocess, 36.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 32.6ms
# Speed: 2.1ms preprocess, 32.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 33.0ms
# Speed: 2.1ms preprocess, 33.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 34.3ms
# Speed: 1.5ms preprocess, 34.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 35.3ms
# Speed: 2.1ms preprocess, 35.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 32.9ms
# Speed: 2.1ms preprocess, 32.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 33.4ms
# Speed: 1.4ms preprocess, 33.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 34.0ms
# Speed: 1.6ms preprocess, 34.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 34.9ms
# Speed: 1.7ms preprocess, 34.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 33.2ms
# Speed: 1.4ms preprocess, 33.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 33.1ms
# Speed: 1.4ms preprocess, 33.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 35.2ms
# Speed: 1.4ms preprocess, 35.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 33.9ms
# Speed: 2.1ms preprocess, 33.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 33.0ms
# Speed: 1.4ms preprocess, 33.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 buss, 33.2ms
# Speed: 1.5ms preprocess, 33.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 36.2ms
# Speed: 1.5ms preprocess, 36.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 33.9ms
# Speed: 1.4ms preprocess, 33.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 33.0ms
# Speed: 2.1ms preprocess, 33.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 35.2ms
# Speed: 2.1ms preprocess, 35.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 34.7ms
# Speed: 2.0ms preprocess, 34.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 33.6ms
# Speed: 2.1ms preprocess, 33.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 33.5ms
# Speed: 1.5ms preprocess, 33.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 34.1ms
# Speed: 1.5ms preprocess, 34.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 36.4ms
# Speed: 2.1ms preprocess, 36.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 34.3ms
# Speed: 1.5ms preprocess, 34.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 33.4ms
# Speed: 1.6ms preprocess, 33.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 33.6ms
# Speed: 1.4ms preprocess, 33.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 35.4ms
# Speed: 1.5ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 33.5ms
# Speed: 2.1ms preprocess, 33.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 33.3ms
# Speed: 1.4ms preprocess, 33.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 34.1ms
# Speed: 1.5ms preprocess, 34.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 34.9ms
# Speed: 1.5ms preprocess, 34.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 34.0ms
# Speed: 2.1ms preprocess, 34.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 33.1ms
# Speed: 1.4ms preprocess, 33.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 33.6ms
# Speed: 2.2ms preprocess, 33.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 35.0ms
# Speed: 1.4ms preprocess, 35.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 33.5ms
# Speed: 1.5ms preprocess, 33.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 33.2ms
# Speed: 1.5ms preprocess, 33.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 34.3ms
# Speed: 2.1ms preprocess, 34.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 35.7ms
# Speed: 1.5ms preprocess, 35.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 34.2ms
# Speed: 2.2ms preprocess, 34.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 33.4ms
# Speed: 1.9ms preprocess, 33.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 33.6ms
# Speed: 2.1ms preprocess, 33.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 34.6ms
# Speed: 1.7ms preprocess, 34.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 35.7ms
# Speed: 1.5ms preprocess, 35.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 33.5ms
# Speed: 1.6ms preprocess, 33.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 33.3ms
# Speed: 1.5ms preprocess, 33.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 34.3ms
# Speed: 1.5ms preprocess, 34.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 36.6ms
# Speed: 1.5ms preprocess, 36.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 33.5ms
# Speed: 2.1ms preprocess, 33.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 33.0ms
# Speed: 1.4ms preprocess, 33.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 33.8ms
# Speed: 2.1ms preprocess, 33.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 34.9ms
# Speed: 1.5ms preprocess, 34.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 35.2ms
# Speed: 1.5ms preprocess, 35.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.6ms
# Speed: 1.7ms preprocess, 33.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 34.6ms
# Speed: 1.6ms preprocess, 34.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 35.3ms
# Speed: 2.1ms preprocess, 35.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 32.5ms
# Speed: 2.2ms preprocess, 32.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 32.7ms
# Speed: 3.0ms preprocess, 32.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.4ms
# Speed: 2.1ms preprocess, 33.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 34.4ms
# Speed: 1.6ms preprocess, 34.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 34.9ms
# Speed: 1.6ms preprocess, 34.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 32.9ms
# Speed: 2.4ms preprocess, 32.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.6ms
# Speed: 1.9ms preprocess, 33.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 35.1ms
# Speed: 1.6ms preprocess, 35.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.9ms
# Speed: 1.6ms preprocess, 33.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.2ms
# Speed: 1.6ms preprocess, 33.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.9ms
# Speed: 1.6ms preprocess, 33.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 35.0ms
# Speed: 1.6ms preprocess, 35.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 34.3ms
# Speed: 1.5ms preprocess, 34.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.6ms
# Speed: 2.1ms preprocess, 33.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 34.8ms
# Speed: 1.6ms preprocess, 34.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.3ms
# Speed: 2.2ms preprocess, 33.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.5ms
# Speed: 1.5ms preprocess, 33.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 35.3ms
# Speed: 1.4ms preprocess, 35.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 34.7ms
# Speed: 1.6ms preprocess, 34.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.4ms
# Speed: 2.0ms preprocess, 33.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 35.9ms
# Speed: 1.6ms preprocess, 35.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.2ms
# Speed: 1.6ms preprocess, 33.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 35.8ms
# Speed: 1.6ms preprocess, 35.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.5ms
# Speed: 2.1ms preprocess, 33.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.1ms
# Speed: 1.7ms preprocess, 33.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.3ms
# Speed: 2.3ms preprocess, 33.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.9ms
# Speed: 2.2ms preprocess, 33.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.2ms
# Speed: 1.6ms preprocess, 33.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.7ms
# Speed: 2.2ms preprocess, 33.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 33.5ms
# Speed: 1.6ms preprocess, 33.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 33.3ms
# Speed: 1.5ms preprocess, 33.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 33.9ms
# Speed: 1.6ms preprocess, 33.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 34.7ms
# Speed: 2.1ms preprocess, 34.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 33.5ms
# Speed: 1.6ms preprocess, 33.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 34.1ms
# Speed: 1.4ms preprocess, 34.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 34.7ms
# Speed: 1.5ms preprocess, 34.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 34.5ms
# Speed: 1.4ms preprocess, 34.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 33.5ms
# Speed: 1.5ms preprocess, 33.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 34.2ms
# Speed: 1.7ms preprocess, 34.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 35.9ms
# Speed: 1.5ms preprocess, 35.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 32.5ms
# Speed: 1.6ms preprocess, 32.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 34.1ms
# Speed: 1.5ms preprocess, 34.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 35.8ms
# Speed: 1.5ms preprocess, 35.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 33.3ms
# Speed: 1.6ms preprocess, 33.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus,